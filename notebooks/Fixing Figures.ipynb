# %%
import pandas as pd
import numpy as np

# %%
train_df =pd.read_csv('/Users/cp/Documents/dsi/capstone2/capstone2/data/train_shuffle_Cap3_set.csv')

# %%
train_df
# Out:
#        brca1   brca2   palb2    pten    tp53     atm    cdh1   chek2     nbn  \
# 0    -0.3099  1.1413 -0.5775  0.3994 -0.4268 -0.3875  1.0911 -0.3548 -0.0734
# 1     1.7061 -0.7560 -0.3430 -0.3649 -1.6057  1.3004  0.4060 -0.1095  0.4133
# 2     0.7953  0.5110  0.6883 -0.2662 -1.6505 -0.8987  0.7472  0.9881 -0.4282
# 3     0.5656 -0.0663  0.6202 -0.3898 -1.3887  1.4198  0.5660 -0.4006 -0.3057
# 4    -0.0378 -0.0068 -0.8137  0.1513 -1.8753 -0.4847 -1.7555 -0.1305  0.1767
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1495  0.1909  1.2547  0.0549  0.3733  0.4856  1.2425  0.4168  1.0626 -0.0492
# 1496  0.0397  0.7002 -0.6513 -0.6873 -0.5098 -0.8756 -0.5237  1.1626 -0.1726
# 1497  2.6197 -0.5534  1.4297 -1.2297 -1.3586  0.4316  0.0457  2.9546  0.0963
# 1498 -0.0625 -0.9064 -1.3023 -0.3825 -1.2944  0.8292  1.4473 -0.1073 -0.0715
# 1499  0.6600 -1.1505 -0.1270  0.5448 -0.0548  0.1998  0.8133  0.2643  0.9845
#
# ...

# %%
lst = 
for i in range 1500:
# Out:
#   File "<ipython-input-4-f72d38dfa946>", line 1
#     lst =
#           ^
# SyntaxError: invalid syntax

# %%
df= train_df.iloc[:11, :]

# %%
lst = []
for i in range(11):
    lst.append(f"Patient:{i}")

# %%
lst
# Out:
# ['Patient:0',
#  'Patient:1',
#  'Patient:2',
#  'Patient:3',
#  'Patient:4',
#  'Patient:5',
#  'Patient:6',
#  'Patient:7',
#  'Patient:8',
#  'Patient:9',
#  'Patient:10']

# %%
df[''] = lst
# Out:
# /Users/cp/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.set_index('')
# Out:
#              brca1   brca2   palb2    pten    tp53     atm    cdh1   chek2  \
#
# Patient:0  -0.3099  1.1413 -0.5775  0.3994 -0.4268 -0.3875  1.0911 -0.3548
# Patient:1   1.7061 -0.7560 -0.3430 -0.3649 -1.6057  1.3004  0.4060 -0.1095
# Patient:2   0.7953  0.5110  0.6883 -0.2662 -1.6505 -0.8987  0.7472  0.9881
# Patient:3   0.5656 -0.0663  0.6202 -0.3898 -1.3887  1.4198  0.5660 -0.4006
# Patient:4  -0.0378 -0.0068 -0.8137  0.1513 -1.8753 -0.4847 -1.7555 -0.1305
# Patient:5  -0.8967  0.3446 -0.9707  0.5703 -0.9155  0.9752  0.7465 -0.7024
# Patient:6   1.2459 -1.3227 -0.4051 -0.6694  0.1744 -0.5758  0.7006 -0.1628
# Patient:7   2.0791 -0.5119  1.8055 -0.7825 -0.3387  0.2892 -0.0753  0.7522
# Patient:8   0.5705  0.0640  1.1190  0.1819 -1.6869 -0.7059  0.5244  0.5795
# Patient:9  -1.1514  1.6393  0.3299 -1.5557 -0.9238 -1.7725 -0.4238  0.5597
# Patient:10 -0.7927  2.6685  0.7758  0.3345  1.2964  0.2850 -0.3224 -0.7288
#
# ...

# %%
df = df.add_suffix(' (gene)')

# %%
df
# Out:
#     brca1 (gene)  brca2 (gene)  palb2 (gene)  pten (gene)  tp53 (gene)  \
# 0        -0.3099        1.1413       -0.5775       0.3994      -0.4268
# 1         1.7061       -0.7560       -0.3430      -0.3649      -1.6057
# 2         0.7953        0.5110        0.6883      -0.2662      -1.6505
# 3         0.5656       -0.0663        0.6202      -0.3898      -1.3887
# 4        -0.0378       -0.0068       -0.8137       0.1513      -1.8753
# 5        -0.8967        0.3446       -0.9707       0.5703      -0.9155
# 6         1.2459       -1.3227       -0.4051      -0.6694       0.1744
# 7         2.0791       -0.5119        1.8055      -0.7825      -0.3387
# 8         0.5705        0.0640        1.1190       0.1819      -1.6869
# 9        -1.1514        1.6393        0.3299      -1.5557      -0.9238
# 10       -0.7927        2.6685        0.7758       0.3345       1.2964
#
#     atm (gene)  cdh1 (gene)  chek2 (gene)  nbn (gene)  nf1 (gene)  ...  \
# ...

# %%
lst = []
for i in range(11):
    lst.append(f"Patient:{i}")

# %%
df= train_df.iloc[:11, :]

# %%
lst = []
for i in range(11):
    lst.append(f"Patient:{i}")

# %%
df[''] = lst
# Out:
# /Users/cp/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df = df.set_index('')

# %%
df
# Out:
#              brca1   brca2   palb2    pten    tp53     atm    cdh1   chek2  \
#
# Patient:0  -0.3099  1.1413 -0.5775  0.3994 -0.4268 -0.3875  1.0911 -0.3548
# Patient:1   1.7061 -0.7560 -0.3430 -0.3649 -1.6057  1.3004  0.4060 -0.1095
# Patient:2   0.7953  0.5110  0.6883 -0.2662 -1.6505 -0.8987  0.7472  0.9881
# Patient:3   0.5656 -0.0663  0.6202 -0.3898 -1.3887  1.4198  0.5660 -0.4006
# Patient:4  -0.0378 -0.0068 -0.8137  0.1513 -1.8753 -0.4847 -1.7555 -0.1305
# Patient:5  -0.8967  0.3446 -0.9707  0.5703 -0.9155  0.9752  0.7465 -0.7024
# Patient:6   1.2459 -1.3227 -0.4051 -0.6694  0.1744 -0.5758  0.7006 -0.1628
# Patient:7   2.0791 -0.5119  1.8055 -0.7825 -0.3387  0.2892 -0.0753  0.7522
# Patient:8   0.5705  0.0640  1.1190  0.1819 -1.6869 -0.7059  0.5244  0.5795
# Patient:9  -1.1514  1.6393  0.3299 -1.5557 -0.9238 -1.7725 -0.4238  0.5597
# Patient:10 -0.7927  2.6685  0.7758  0.3345  1.2964  0.2850 -0.3224 -0.7288
#
# ...

# %%
df = df.add_suffix(' (gene)')

# %%
df
# Out:
#             brca1 (gene)  brca2 (gene)  palb2 (gene)  pten (gene)  \
#
# Patient:0        -0.3099        1.1413       -0.5775       0.3994
# Patient:1         1.7061       -0.7560       -0.3430      -0.3649
# Patient:2         0.7953        0.5110        0.6883      -0.2662
# Patient:3         0.5656       -0.0663        0.6202      -0.3898
# Patient:4        -0.0378       -0.0068       -0.8137       0.1513
# Patient:5        -0.8967        0.3446       -0.9707       0.5703
# Patient:6         1.2459       -1.3227       -0.4051      -0.6694
# Patient:7         2.0791       -0.5119        1.8055      -0.7825
# Patient:8         0.5705        0.0640        1.1190       0.1819
# Patient:9        -1.1514        1.6393        0.3299      -1.5557
# Patient:10       -0.7927        2.6685        0.7758       0.3345
#
#             tp53 (gene)  atm (gene)  cdh1 (gene)  chek2 (gene)  nbn (gene)  \
#
# Patient:0       -0.4268     -0.3875       1.0911       -0.3548     -0.0734
# ...

# %%
0.35
