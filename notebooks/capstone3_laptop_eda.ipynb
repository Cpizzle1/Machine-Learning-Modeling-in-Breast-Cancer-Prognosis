# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/Users/cpsanto/Documents/dsi/capstone2/capstone2/data/METABRIC_RNA_Mutation.csv', index_col = 0)
# Out:
# /Users/cpsanto/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3147: DtypeWarning: Columns (678,688,690,692) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#             age_at_diagnosis type_of_breast_surgery    cancer_type  \
# patient_id
# 0                      75.65             MASTECTOMY  Breast Cancer
# 2                      43.19      BREAST CONSERVING  Breast Cancer
# 5                      48.87             MASTECTOMY  Breast Cancer
# 6                      47.68             MASTECTOMY  Breast Cancer
# 8                      76.97             MASTECTOMY  Breast Cancer
# ...                      ...                    ...            ...
# 7295                   43.10      BREAST CONSERVING  Breast Cancer
# 7296                   42.88             MASTECTOMY  Breast Cancer
# 7297                   62.90             MASTECTOMY  Breast Cancer
# 7298                   61.16             MASTECTOMY  Breast Cancer
# 7299                   60.02      BREAST CONSERVING  Breast Cancer
#
#                                  cancer_type_detailed cellularity  \
# patient_id
# 0                    Breast Invasive Ductal Carcinoma         NaN
# ...

# %%
df['type_of_breast_surgery'] = df['type_of_breast_surgery'].apply(lambda x: x=1 if x== 'MASTECTOMY' else x =0, axis=1)
# Out:
#   File "<ipython-input-10-78f9e4af40a0>", line 1
#     df['type_of_breast_surgery'] = df['type_of_breast_surgery'].apply(lambda x: x=1 if x== 'MASTECTOMY' else x =0, axis=1)
#                                                                                                                ^
# SyntaxError: invalid syntax

# %%
# df['type_of_breast_surgery'] = df['type_of_breast_surgery'].str.replace('MASTECTOMY', 0)
df.type_of_breast_surgery = df.type_of_breast_surgery.map( {'MASTECTOMY':1 , 'BREAST CONSERVING':0} )

# %%
df
# Out:
#             age_at_diagnosis  type_of_breast_surgery    cancer_type  \
# patient_id
# 0                      75.65                     1.0  Breast Cancer
# 2                      43.19                     0.0  Breast Cancer
# 5                      48.87                     1.0  Breast Cancer
# 6                      47.68                     1.0  Breast Cancer
# 8                      76.97                     1.0  Breast Cancer
# ...                      ...                     ...            ...
# 7295                   43.10                     0.0  Breast Cancer
# 7296                   42.88                     1.0  Breast Cancer
# 7297                   62.90                     1.0  Breast Cancer
# 7298                   61.16                     1.0  Breast Cancer
# 7299                   60.02                     0.0  Breast Cancer
#
#                                  cancer_type_detailed cellularity  \
# patient_id
# ...

# %%
df.cancer_type_detailed.value_counts()
# Out:
# Breast Invasive Ductal Carcinoma             1500
# Breast Mixed Ductal and Lobular Carcinoma     207
# Breast Invasive Lobular Carcinoma             142
# Breast Invasive Mixed Mucinous Carcinoma       22
# Breast                                         17
# Metaplastic Breast Cancer                       1
# Name: cancer_type_detailed, dtype: int64

# %%
df
# Out:
#             age_at_diagnosis  type_of_breast_surgery    cancer_type  \
# patient_id
# 0                      75.65                     1.0  Breast Cancer
# 2                      43.19                     0.0  Breast Cancer
# 5                      48.87                     1.0  Breast Cancer
# 6                      47.68                     1.0  Breast Cancer
# 8                      76.97                     1.0  Breast Cancer
# ...                      ...                     ...            ...
# 7295                   43.10                     0.0  Breast Cancer
# 7296                   42.88                     1.0  Breast Cancer
# 7297                   62.90                     1.0  Breast Cancer
# 7298                   61.16                     1.0  Breast Cancer
# 7299                   60.02                     0.0  Breast Cancer
#
#                                  cancer_type_detailed cellularity  \
# patient_id
# ...

# %%
df.columns[:35]
# Out:
# Index(['age_at_diagnosis', 'type_of_breast_surgery', 'cancer_type',
#        'cancer_type_detailed', 'cellularity', 'chemotherapy',
#        'pam50_+_claudin-low_subtype', 'cohort', 'er_status_measured_by_ihc',
#        'er_status', 'neoplasm_histologic_grade',
#        'her2_status_measured_by_snp6', 'her2_status',
#        'tumor_other_histologic_subtype', 'hormone_therapy',
#        'inferred_menopausal_state', 'integrative_cluster',
#        'primary_tumor_laterality', 'lymph_nodes_examined_positive',
#        'mutation_count', 'nottingham_prognostic_index', 'oncotree_code',
#        'overall_survival_months', 'overall_survival', 'pr_status',
#        'radio_therapy', '3-gene_classifier_subtype', 'tumor_size',
#        'tumor_stage', 'death_from_cancer', 'brca1', 'brca2', 'palb2', 'pten',
#        'tp53'],
#       dtype='object')

# %%
df.overall_survival
# Out:
# patient_id
# 0       1
# 2       1
# 5       0
# 6       1
# 8       0
#        ..
# 7295    1
# 7296    0
# 7297    0
# 7298    0
# 7299    0
# Name: overall_survival, Length: 1904, dtype: int64

# %%
df
# Out:
#             age_at_diagnosis  type_of_breast_surgery    cancer_type  \
# patient_id
# 0                      75.65                     1.0  Breast Cancer
# 2                      43.19                     0.0  Breast Cancer
# 5                      48.87                     1.0  Breast Cancer
# 6                      47.68                     1.0  Breast Cancer
# 8                      76.97                     1.0  Breast Cancer
# ...                      ...                     ...            ...
# 7295                   43.10                     0.0  Breast Cancer
# 7296                   42.88                     1.0  Breast Cancer
# 7297                   62.90                     1.0  Breast Cancer
# 7298                   61.16                     1.0  Breast Cancer
# 7299                   60.02                     0.0  Breast Cancer
#
#                                  cancer_type_detailed cellularity  \
# patient_id
# ...

# %%
df['pam50_+_claudin-low_subtype'].value_counts()
# Out:
# LumA           679
# LumB           461
# Her2           220
# Basal          199
# claudin-low    199
# Normal         140
# NC               6
# Name: pam50_+_claudin-low_subtype, dtype: int64

# %%
df.tumor_other_histologic_subtype.value_counts()
# Out:
# Ductal/NST             1454
# Mixed                   207
# Lobular                 142
# Medullary                25
# Mucinous                 22
# Tubular/ cribriform      21
# Other                    17
# Metaplastic               1
# Name: tumor_other_histologic_subtype, dtype: int64

# %%
df.mutation_count.value_counts().hist()
# Out:
# <AxesSubplot:>

# %%
df.mutation_count.hist(bins = 30)
# Out:
# <AxesSubplot:>

# %%
df.mutation_count.value_counts()
# Out:
# 5.0     268
# 4.0     248
# 6.0     232
# 3.0     229
# 2.0     193
# 7.0     168
# 8.0     121
# 1.0     107
# 9.0      90
# 10.0     61
# 11.0     38
# 12.0     25
# 13.0     17
# 14.0     16
# 15.0     11
# 16.0      8
# 17.0      5
# 22.0      4
# 20.0      4
# 19.0      2
# 23.0      2
# 18.0      2
# 21.0      1
# 28.0      1
# 26.0      1
# 24.0      1
# 40.0      1
# 46.0      1
# 30.0      1
# 80.0      1
# Name: mutation_count, dtype: int64

# %%
fig, ax = plt.subplots()
ax.hist(df.mutation_count, bins = 30)
ax.set_xlim(0,30)
# Out:
# (0.0, 30.0)

# %%
df
# Out:
#             age_at_diagnosis  type_of_breast_surgery    cancer_type  \
# patient_id
# 0                      75.65                     1.0  Breast Cancer
# 2                      43.19                     0.0  Breast Cancer
# 5                      48.87                     1.0  Breast Cancer
# 6                      47.68                     1.0  Breast Cancer
# 8                      76.97                     1.0  Breast Cancer
# ...                      ...                     ...            ...
# 7295                   43.10                     0.0  Breast Cancer
# 7296                   42.88                     1.0  Breast Cancer
# 7297                   62.90                     1.0  Breast Cancer
# 7298                   61.16                     1.0  Breast Cancer
# 7299                   60.02                     0.0  Breast Cancer
#
#                                  cancer_type_detailed cellularity  \
# patient_id
# ...

# %%
df.integrative_cluster.value_counts()
# Out:
# 8       289
# 3       282
# 4ER+    244
# 10      219
# 5       184
# 7       182
# 9       142
# 1       132
# 6        84
# 4ER-     74
# 2        72
# Name: integrative_cluster, dtype: int64

# %%
mut_filt = df.mutation_count>10

# %%
high_mutation_df = df[mut_filt]

# %%
high_mutation_df.mutation_count.value_counts()
# Out:
# 11.0    38
# 12.0    25
# 13.0    17
# 14.0    16
# 15.0    11
# 16.0     8
# 17.0     5
# 22.0     4
# 20.0     4
# 23.0     2
# 18.0     2
# 19.0     2
# 26.0     1
# 28.0     1
# 24.0     1
# 40.0     1
# 21.0     1
# 46.0     1
# 30.0     1
# 80.0     1
# Name: mutation_count, dtype: int64

# %%
high_mutation_df.death_from_cancer.value_counts()
# Out:
# Living                  54
# Died of Disease         44
# Died of Other Causes    43
# Name: death_from_cancer, dtype: int64

# %%
df.death_from_cancer= df.death_from_cancer.map( {'Died of Disease':1 , 'Died of Other Causes':0, 'Living':0} )

# %%
df
# Out:
#             age_at_diagnosis type_of_breast_surgery    cancer_type  \
# patient_id
# 0                      75.65             MASTECTOMY  Breast Cancer
# 2                      43.19      BREAST CONSERVING  Breast Cancer
# 5                      48.87             MASTECTOMY  Breast Cancer
# 6                      47.68             MASTECTOMY  Breast Cancer
# 8                      76.97             MASTECTOMY  Breast Cancer
# ...                      ...                    ...            ...
# 7295                   43.10      BREAST CONSERVING  Breast Cancer
# 7296                   42.88             MASTECTOMY  Breast Cancer
# 7297                   62.90             MASTECTOMY  Breast Cancer
# 7298                   61.16             MASTECTOMY  Breast Cancer
# 7299                   60.02      BREAST CONSERVING  Breast Cancer
#
#                                  cancer_type_detailed cellularity  \
# patient_id
# 0                    Breast Invasive Ductal Carcinoma         NaN
# ...

# %%
df.death_from_cancer
# Out:
# patient_id
# 0       0.0
# 2       0.0
# 5       1.0
# 6       0.0
# 8       1.0
#        ...
# 7295    0.0
# 7296    1.0
# 7297    1.0
# 7298    0.0
# 7299    0.0
# Name: death_from_cancer, Length: 1904, dtype: float64

# %%
df.columns[500:]
# Out:
# Index(['prkd1', 'ran', 'rdh5', 'sdc4', 'serpini1', 'shbg', 'slc29a1', 'sox9',
#        'spry2', 'srd5a1',
#        ...
#        'mtap_mut', 'ppp2cb_mut', 'smarcd1_mut', 'nras_mut', 'ndfip1_mut',
#        'hras_mut', 'prps2_mut', 'smarcb1_mut', 'stmn2_mut', 'siah1_mut'],
#       dtype='object', length=192)

# %%
len(df.columns)
# Out:
# 692

# %%
mut_list = []
for i in df.columns:
    if '_mut' in i:
        mut_list.append(i)

# %%
len(mut_list)
# Out:
# 173

# %%
df_mut = df.iloc[:,519:]

# %%
df_mut
# Out:
#            pik3ca_mut tp53_mut muc16_mut ahnak2_mut kmt2c_mut syne1_mut  \
# patient_id
# 0                   0        0         0          0         0         0
# 2                   0    H178P         0          0         0         0
# 5              H1047R        0         0          0         0         0
# 6               E542K        0         0          0         0         0
# 8                   0    S241F         0          0         0         0
# ...               ...      ...       ...        ...       ...       ...
# 7295            E542K        0         0          0         0         0
# 7296                0    M237I         0          0         0         0
# 7297                0        0         0          0         0         0
# 7298                0        0         0     V3102M         0         0
# 7299                0        0         0          0         0         0
#
#                          gata3_mut map3k1_mut ahnak_mut dnah11_mut  ...  \
# ...

# %%
# df['type_of_breast_surgery'] = df['type_of_breast_surgery'].apply(lambda x: x=1 if x== 'MASTECTOMY' else x =0, axis=1)

df_mut.apply(lambda x:1 if x!='0' else x =0)
# Out:
#   File "<ipython-input-72-94f35552b635>", line 3
#     df_mut.apply(lambda x:1 if x!='0' else x =0)
#                 ^
# SyntaxError: lambda cannot contain assignment

# %%
# df_mut = df_mut.apply(lambda x: 1 if x != 0 else 1)
df_mut2 = df_mut.applymap(lambda x: 0 if x=='0' else 1)

# %%
df_mut.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1904 entries, 0 to 7299
# Data columns (total 173 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   pik3ca_mut     object
#  1   tp53_mut       object
#  2   muc16_mut      object
#  3   ahnak2_mut     object
#  4   kmt2c_mut      object
#  5   syne1_mut      object
#  6   gata3_mut      object
#  7   map3k1_mut     object
#  8   ahnak_mut      object
#  9   dnah11_mut     object
#  10  cdh1_mut       object
#  11  dnah2_mut      object
#  12  kmt2d_mut      object
#  13  ush2a_mut      object
#  14  ryr2_mut       object
#  15  dnah5_mut      object
#  16  herc2_mut      object
#  17  pde4dip_mut    object
#  18  akap9_mut      object
#  19  tg_mut         object
#  20  birc6_mut      object
#  21  utrn_mut       object
#  22  tbx3_mut       object
#  23  col6a3_mut     object
#  24  arid1a_mut     object
#  25  lama2_mut      object
#  26  notch1_mut     object
#  27  cbfb_mut       object
# ...

# %%
for i in df_mut:
    if i =='0':
        i = 0
    else:
        i =1

# %%
df_mut.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1904 entries, 0 to 7299
# Data columns (total 173 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   pik3ca_mut     object
#  1   tp53_mut       object
#  2   muc16_mut      object
#  3   ahnak2_mut     object
#  4   kmt2c_mut      object
#  5   syne1_mut      object
#  6   gata3_mut      object
#  7   map3k1_mut     object
#  8   ahnak_mut      object
#  9   dnah11_mut     object
#  10  cdh1_mut       object
#  11  dnah2_mut      object
#  12  kmt2d_mut      object
#  13  ush2a_mut      object
#  14  ryr2_mut       object
#  15  dnah5_mut      object
#  16  herc2_mut      object
#  17  pde4dip_mut    object
#  18  akap9_mut      object
#  19  tg_mut         object
#  20  birc6_mut      object
#  21  utrn_mut       object
#  22  tbx3_mut       object
#  23  col6a3_mut     object
#  24  arid1a_mut     object
#  25  lama2_mut      object
#  26  notch1_mut     object
#  27  cbfb_mut       object
# ...

# %%
# for k, v in df_mut.iteritems():
#     if v == '0':
#         v = 0
#     else:
#         v =1

# %%
for i in df_mut.columns:
    print(df_mut.i.value_counts())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-f8e6eb5f01b8> in <module>
#       1 for i in df_mut.columns:
# ----> 2     print(df_mut.i.value_counts())
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'i'

# %%
for i in df_mut2.columns:
#     print(i)
    print(df_mut2[i].value_counts())
# Out:
# 0    1109
# 1     795
# Name: pik3ca_mut, dtype: int64
# 0    1245
# 1     659
# Name: tp53_mut, dtype: int64
# 0    1578
# 1     326
# Name: muc16_mut, dtype: int64
# 0    1593
# 1     311
# Name: ahnak2_mut, dtype: int64
# 0    1670
# 1     234
# Name: kmt2c_mut, dtype: int64
# 0    1672
# 1     232
# Name: syne1_mut, dtype: int64
# 0    1674
# 1     230
# Name: gata3_mut, dtype: int64
# 0    1706
# 1     198
# Name: map3k1_mut, dtype: int64
# 0    1728
# 1     176
# Name: ahnak_mut, dtype: int64
# 0    1729
# 1     175
# Name: dnah11_mut, dtype: int64
# 0    1732
# 1     172
# Name: cdh1_mut, dtype: int64
# 0    1754
# 1     150
# Name: dnah2_mut, dtype: int64
# 0    1764
# 1     140
# Name: kmt2d_mut, dtype: int64
# 0    1765
# 1     139
# Name: ush2a_mut, dtype: int64
# 0    1769
# 1     135
# Name: ryr2_mut, dtype: int64
# 0    1772
# 1     132
# Name: dnah5_mut, dtype: int64
# 0    1776
# 1     128
# Name: herc2_mut, dtype: int64
# 0    1786
# 1     118
# ...

# %%
df.columns[:50]
# Out:
# Index(['age_at_diagnosis', 'type_of_breast_surgery', 'cancer_type',
#        'cancer_type_detailed', 'cellularity', 'chemotherapy',
#        'pam50_+_claudin-low_subtype', 'cohort', 'er_status_measured_by_ihc',
#        'er_status', 'neoplasm_histologic_grade',
#        'her2_status_measured_by_snp6', 'her2_status',
#        'tumor_other_histologic_subtype', 'hormone_therapy',
#        'inferred_menopausal_state', 'integrative_cluster',
#        'primary_tumor_laterality', 'lymph_nodes_examined_positive',
#        'mutation_count', 'nottingham_prognostic_index', 'oncotree_code',
#        'overall_survival_months', 'overall_survival', 'pr_status',
#        'radio_therapy', '3-gene_classifier_subtype', 'tumor_size',
#        'tumor_stage', 'death_from_cancer', 'brca1', 'brca2', 'palb2', 'pten',
#        'tp53', 'atm', 'cdh1', 'chek2', 'nbn', 'nf1', 'stk11', 'bard1', 'mlh1',
#        'msh2', 'msh6', 'pms2', 'epcam', 'rad51c', 'rad51d', 'rad50'],
#       dtype='object')

# %%
df.overall_survival_months.describe(include = 'all')
# Out:
# count    1904.000000
# mean      125.121324
# std        76.334148
# min         0.000000
# 25%        60.825000
# 50%       115.616667
# 75%       184.716667
# max       355.200000
# Name: overall_survival_months, dtype: float64

# %%
df.age_at_diagnosis.describe()
# Out:
# count    1904.000000
# mean       61.087054
# std        12.978711
# min        21.930000
# 25%        51.375000
# 50%        61.770000
# 75%        70.592500
# max        96.290000
# Name: age_at_diagnosis, dtype: float64

# %%
df.tumor_size.value_counts()
# Out:
# 20.00    229
# 25.00    166
# 30.00    155
# 15.00    147
# 18.00     75
#         ...
# 13.80      1
# 25.10      1
# 2.12       1
# 17.20      1
# 5.50       1
# Name: tumor_size, Length: 111, dtype: int64

# %%
df
# Out:
#             age_at_diagnosis type_of_breast_surgery    cancer_type  \
# patient_id
# 0                      75.65             MASTECTOMY  Breast Cancer
# 2                      43.19      BREAST CONSERVING  Breast Cancer
# 5                      48.87             MASTECTOMY  Breast Cancer
# 6                      47.68             MASTECTOMY  Breast Cancer
# 8                      76.97             MASTECTOMY  Breast Cancer
# ...                      ...                    ...            ...
# 7295                   43.10      BREAST CONSERVING  Breast Cancer
# 7296                   42.88             MASTECTOMY  Breast Cancer
# 7297                   62.90             MASTECTOMY  Breast Cancer
# 7298                   61.16             MASTECTOMY  Breast Cancer
# 7299                   60.02      BREAST CONSERVING  Breast Cancer
#
#                                  cancer_type_detailed cellularity  \
# patient_id
# 0                    Breast Invasive Ductal Carcinoma         NaN
# ...

# %%
df.loc[:,'brca1':'ugt2b7']
# Out:
#              brca1   brca2   palb2    pten    tp53     atm    cdh1   chek2  \
# patient_id
# 0          -1.3990 -0.5738 -1.6217  1.4524  0.3504  1.1517  0.0348  0.1266
# 2          -1.3800  0.2777 -1.2154  0.5296 -0.0136 -0.2659  1.3594  0.7961
# 5           0.0670 -0.8426  0.2114 -0.3326  0.5141 -0.0803  1.1398  0.4187
# 6           0.6744 -0.5428 -1.6592  0.6369  1.6708 -0.8880  1.2491 -1.1889
# 8           1.2932 -0.9039 -0.7219  0.2168  0.3484  0.3897  0.9131  0.9356
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 7295        0.1563  0.5543 -0.6149  0.4572  1.3822 -0.0537 -0.1323  0.2837
# 7296        0.1343  0.9128  1.3017  0.7383  0.1841  0.0028  0.1243  2.2040
# 7297        1.8107 -0.2608  0.4006 -0.2985  0.0356 -0.1620  1.5486  1.5309
# 7298       -1.2746 -1.7695 -0.3454 -0.3850  0.6689  1.4531  1.0956 -0.0948
# 7299       -0.7525  0.7352  0.6448 -0.3241 -0.0434  1.7272  0.7193  3.1425
#
# ...

# %%
df.loc[:,:'brca1'].shape
# Out:
# (1904, 31)

# %%
df_clinical = df.loc[:,:'death_from_cancer']

# %%
df_clinical.type_of_breast_surgery.value_counts()
# Out:
# MASTECTOMY           1127
# BREAST CONSERVING     755
# Name: type_of_breast_surgery, dtype: int64

# %%
df_clinical.columns
# Out:
# Index(['age_at_diagnosis', 'type_of_breast_surgery', 'cancer_type',
#        'cancer_type_detailed', 'cellularity', 'chemotherapy',
#        'pam50_+_claudin-low_subtype', 'cohort', 'er_status_measured_by_ihc',
#        'er_status', 'neoplasm_histologic_grade',
#        'her2_status_measured_by_snp6', 'her2_status',
#        'tumor_other_histologic_subtype', 'hormone_therapy',
#        'inferred_menopausal_state', 'integrative_cluster',
#        'primary_tumor_laterality', 'lymph_nodes_examined_positive',
#        'mutation_count', 'nottingham_prognostic_index', 'oncotree_code',
#        'overall_survival_months', 'overall_survival', 'pr_status',
#        'radio_therapy', '3-gene_classifier_subtype', 'tumor_size',
#        'tumor_stage', 'death_from_cancer'],
#       dtype='object')
